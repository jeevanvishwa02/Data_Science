# %% [markdown]
# <a href="https://colab.research.google.com/github/jeevanvishwa02/Data_Science/blob/main/Theory_and_Regression_using_FFNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trainable Parms and NN Regression (DL)
#
# Theory and application of neural networks for regression!

# %% [markdown]
# # **Part 1.** Recreate the math in the `model.summmary()` below
#
# Understanding the concept of weights and biases.
#
# Imagine that your data set has 20,000 rows and 50 columns. You are to count the trainable parameters and show the output shape for each layer in the network

# %% [markdown]
# _______________________________________________________
# ## Rubric
# Recreate the model summary above using the outputs from your own 7 digit random number

# %%
# leave this as 50 for now
n_features = 50

# put your 7 digit Student ID, replace the 1234567
# if you have a 0 in your studentID, please replace it with a 5 (so the math works out!)
A = 3
B = 5
C = 1
D = 6
E = 5
F = 1
G = 4

# %%
# now run this code
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(A, activation='relu', input_shape=(n_features,))) # see how we didnt hard code a 50 here?
model.add(Dense(B, activation='relu'))
model.add(Dense(C, activation='relu'))
model.add(Dense(D, activation='relu'))
model.add(Dense(E, activation='relu'))
model.add(Dense(F, activation='relu'))
model.add(Dense(G, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_19 (Dense)            (None, 3)                 153
#
#  dense_20 (Dense)            (None, 5)                 20
#
#  dense_21 (Dense)            (None, 1)                 6
#
#  dense_22 (Dense)            (None, 6)                 12
#
#  dense_23 (Dense)            (None, 5)                 35
#
#  dense_24 (Dense)            (None, 1)                 6
#
#  dense_25 (Dense)            (None, 4)                 8
#
#  dense_26 (Dense)            (None, 1)                 5
#
# ...
# Total params: 245
# Trainable params: 245
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make sure you add a nice subheader for each layer in the network!

# %% [markdown]
# ### Layer `dense` (153 trainable parameters, 150 weights, 3 bias)
# 150 weights and 3 bias. There are 50 inputs going into a hidden layer with 3 hidden units, and there is 1 bias for each of the 3 hidden units in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $50*3 + 3 = 153$

# %% [markdown]
# ### Layer `dense1` (20 trainable parameters, 15 weights, 5 bias)
# 15 weights and 5 bias. There are 3 inputs going into a hidden layer with 5 hidden units, and there is 1 bias for each of the 5 hidden units in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $3*5 + 5 = 20$

# %% [markdown]
# ### Layer `dense2` (6 trainable parameters, 5 weights, 1 bias)
# 5 weights and 1 bias. There are 5 inputs going into a hidden layer with 1 hidden units, and there is 1 bias for each of the 1 hidden unit in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $5*1 + 1 = 6$

# %% [markdown]
# ### Layer `dense3` (12 trainable parameters, 6 weights, 6 bias)
# 6 weights and 6 bias. There is 1 input going into a hidden layer with 6 hidden units, and there is 1 bias for each of the 6 hidden units in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $1*6 + 6 = 12$

# %% [markdown]
# ### Layer `dense4` (35 trainable parameters, 30 weights, 5 bias)
# 30 weights and 5 bias. There are 6 inputs going into a hidden layer with 5 hidden units, and there is 1 bias for each of the 5 hidden units in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $6*5 + 5 = 35$

# %% [markdown]
# ### Layer `dense5` (6 trainable parameters, 5 weights, 1 bias)
# 5 weights and 1 bias. There are 5 inputs going into a hidden layer with 1 hidden unit, and there is 1 bias for each of the 1 hidden unit in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $5*1 + 1 = 6$

# %% [markdown]
# ### Layer `dense6` (8 trainable parameters, 4 weights, 4 bias)
# 4 weights and 4 bias. There are 4 inputs going into a hidden layer with 4 hidden units, and there is 1 bias for each of the 4 hidden units in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $4*1 + 4 = 8$

# %% [markdown]
# ### Layer `dense7` (5 trainable parameters, 4 weights, 1 bias)
# 4 weights and 1 bias. There are 4 inputs going into a hidden layer with 1 hidden units, and there is 1 bias for each of the 1 hidden units in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $4*1 + 1 = 5$

# %% [markdown]
# #  **Part 2.** Fit and evaluate a model using real-world data
# This is clean data to work with 😃
#
# These are hourly observations of weather vs. energy (electricity) consumption in New England. This is a real-world dataset

# %% [markdown]
# ## Rubric for modeling
#
#
# **Prep the data :**
# * Read the energy/weather data: https://drive.google.com/file/d/1ylQJKeCyMStvvMzRGDo8nR1TI8_3xGgP/view?usp=sharing
# * Select columns for modeling
#   * Check for missing values and inspect data types
#   * The target variable is last column df['MWh']
#   * You can use as many columns for X, but you may want to just stick to df['tmpf'] through `df['sknt']` along with the df['HE'] (which is the hour of the day).
#     * A data dictionary for the weather data can be found at the bottom of this website: https://mesonet.agron.iastate.edu/request/download.phtml
#   * If you want to be an overachiever (and I think you should!), feel free to do some feature engineering (but this is optional)
# .
# * Use an 80/20 train/val split
# * Apply min/max or standard scalar to X_train and apply to X_test
#
#
# **Build, compile and fit a model **
# * Use as many or as few layers as you would like, with as many or as few hidden units as you would like.
# * Use  dropout and early stopping (make sure you return the best weights, you can choose what value of patience to use.)
#   * Here are some references and a nice example of using dropout - values between 0.2 and 0.5 work well. https://machinelearningknowledge.ai/keras-dropout-layer-explained-for-beginners/
#
# **Evaluate the model :**
# * Make a learning curve for train and validation loss
# * Create a scatterplot of actual vs. predicted for each partition
# * Calculate MAE, RMSE and R2 for each partition.

# %% [markdown]
# ## Import the Packages

# %%
# import modules
# for general data analysis/plotting
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# for data prep
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# neural net modules
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping

# %% [markdown]
# ## Read the Data

# %%
# https://drive.google.com/file/d/1ylQJKeCyMStvvMzRGDo8nR1TI8_3xGgP/view
# !gdown 1ylQJKeCyMStvvMzRGDo8nR1TI8_3xGgP
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ylQJKeCyMStvvMzRGDo8nR1TI8_3xGgP
# To: /content/cleanweather_energy.csv
# 100% 25.4k/25.4k [00:00<00:00, 24.9MB/s]

# %%
df = pd.read_csv('cleanweather_energy.csv')
df.shape
# Out:
# (96, 37)

# %% [markdown]
# There are 96 rows and 37 columns in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   valid              96 non-null     object
#  1   station            96 non-null     object
#  2   valid.1            96 non-null     object
#  3   lon                96 non-null     float64
#  4   lat                96 non-null     float64
#  5   tmpf               96 non-null     float64
#  6   dwpf               96 non-null     float64
#  7   relh               96 non-null     float64
#  8   drct               96 non-null     float64
#  9   sknt               96 non-null     float64
#  10  p01i               96 non-null     float64
#  11  alti               96 non-null     float64
#  12  mslp               96 non-null     float64
#  13  vsby               96 non-null     float64
#  14  gust               22 non-null     float64
# ...

# %%
df.head(1)
# Out:
#                  valid station              valid.1      lon      lat  tmpf  \
# 0  2020-08-25 00:00:00     BDL  2020-08-25 00:55:00 -72.6825  41.9381  73.9
#
#    dwpf   relh   drct  sknt  ...  peak_wind_gust  peak_wind_drct  \
# 0  69.1  84.97  240.0   3.0  ...               M               M
#
#    peak_wind_time  feel                                              metar  \
# 0               M     M  KBDL 250055Z AUTO 24002KT 10SM CLR 23/21 A2990...
#
#   snowdepth  H                 Date HE       MWh
# 0         M  D  2020-08-25 00:00:00  0  14986.78
#
# [1 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['valid', 'station', 'valid.1', 'lon', 'lat', 'tmpf', 'dwpf', 'relh',
#        'drct', 'sknt', 'p01i', 'alti', 'mslp', 'vsby', 'gust', 'skyc1',
#        'skyc2', 'skyc3', 'skyc4', 'skyl1', 'skyl2', 'skyl3', 'skyl4',
#        'wxcodes', 'ice_accretion_1hr', 'ice_accretion_3hr',
#        'ice_accretion_6hr', 'peak_wind_gust', 'peak_wind_drct',
#        'peak_wind_time', 'feel', 'metar', 'snowdepth', 'H', 'Date', 'HE',
#        'MWh'],
#       dtype='object')

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# ### Check for Missing Values

# %%
df.isna().sum()
# Out:
# valid                 0
# station               0
# valid.1               0
# lon                   0
# lat                   0
# tmpf                  0
# dwpf                  0
# relh                  0
# drct                  0
# sknt                  0
# p01i                  0
# alti                  0
# mslp                  0
# vsby                  0
# gust                 74
# skyc1                 0
# skyc2                 0
# skyc3                 0
# skyc4                 0
# skyl1                 0
# skyl2                 0
# skyl3                 0
# skyl4                 0
# wxcodes               0
# ice_accretion_1hr     0
# ice_accretion_3hr     0
# ice_accretion_6hr     0
# peak_wind_gust        0
# peak_wind_drct        0
# peak_wind_time        0
# feel                  0
# metar                 0
# snowdepth             0
# H                     0
# Date                  0
# HE                    0
# MWh                   0
# dtype: int64

# %% [markdown]
# There are 74 missing values in column gust. However only following columns will be considered for this analysis
#
# ['tmpf', 'dwpf', 'relh', 'drct', 'sknt', 'HE', 'MWh']

# %%
df2=df[['tmpf', 'dwpf', 'relh', 'drct', 'sknt', 'HE', 'MWh']]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tmpf    96 non-null     float64
#  1   dwpf    96 non-null     float64
#  2   relh    96 non-null     float64
#  3   drct    96 non-null     float64
#  4   sknt    96 non-null     float64
#  5   HE      96 non-null     int64
#  6   MWh     96 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 5.4 KB

# %% [markdown]
# All the columns in the new dataframe are continuous variables

# %%
#Check for missing values
df2.isna().sum()
# Out:
# tmpf    0
# dwpf    0
# relh    0
# drct    0
# sknt    0
# HE      0
# MWh     0
# dtype: int64

# %% [markdown]
# There are no missing values in the new dataframe

# %% [markdown]
# ## Data Exploration

# %%
df2.describe()
# Out:
#             tmpf       dwpf        relh        drct       sknt         HE  \
# count  96.000000  96.000000   96.000000   96.000000  96.000000  96.000000
# mean   69.483333  56.632292   67.607083  291.250000   8.739583  11.500000
# std     8.234493   8.813691   21.687167   64.109282   5.284027   6.958524
# min    57.000000  37.900000   26.080000   80.000000   2.000000   0.000000
# 25%    62.100000  48.675000   49.732500  237.500000   5.000000   5.750000
# 50%    68.550000  59.000000   66.275000  320.000000   7.000000  11.500000
# 75%    75.000000  62.700000   90.400000  340.000000  11.250000  17.250000
# max    90.000000  70.000000  100.000000  360.000000  30.000000  23.000000
#
#                MWh
# count     96.00000
# mean   14443.88250
# std     2507.91228
# min    10857.18000
# 25%    12850.06750
# 50%    13903.91500
# 75%    15319.71000
# max    21359.46000

# %%
# For Target variable Mwh

# mean
print("Mean of target variable MWh: ",df2['MWh'].mean() )
print("Mean of target variable MWh: ",df2['MWh'].median() )

print("Here is the 10th (90th) percentiles, which means 10% (90%) of the data lies below this value:")
df2['MWh'].quantile([0.1, 0.25, 0.5, 0.75, 0.9])
# Out:
# Mean of target variable MWh:  14443.8825
# Mean of target variable MWh:  13903.915
# Here is the 10th (90th) percentiles, which means 10% (90%) of the data lies below this value:
# 0.10    11525.9600
# 0.25    12850.0675
# 0.50    13903.9150
# 0.75    15319.7100
# 0.90    18277.5950
# Name: MWh, dtype: float64

# %%
import seaborn as sns
sns.heatmap(df2.corr(),annot = True);

# %% [markdown]
# 1.   drct and MWh does not have a strong correlation
# 2.   Similarly for relh and MWh

# %%
# show histograms of ALL variables
# histograms allow you to see the shape of the distribution... binned data...
df2.hist() # this makes the histogram plot
plt.tight_layout() # space stuff out nicely (what happens without this?)
plt.show()

# %%
# boxplots
df2.boxplot('MWh') # grab the dataframe then select the 'medv' column
plt.ylabel('Median Watt per Hour ')
plt.title("Boxplot of MWH ")
plt.show()

# %%
df2.columns
# Out:
# Index(['tmpf', 'dwpf', 'relh', 'drct', 'sknt', 'HE', 'MWh'], dtype='object')

# %%
sns.pairplot(
    data=df2, 
    aspect=.85);

# %% [markdown]
# 1.   tmpf,dwpf and sknt are trending linearly with Mwh
# 2.   There is an outlier in sknt column which is clearly stading away from rest of the observations. (Will be imputing the value with mean of the dataset)
# 3. drct has two outliers which are not in usual range

# %% [markdown]
# ### Data Imputation

# %%
#Check for count of outliers based on standard definition of lower quartile and upper quartile (2*IQR is used)
#Insur_data_cont
df2.describe()
Q1 = df2.quantile(0.25)
Q3 = df2.quantile(0.75)
IQR = Q3 - Q1
#print(IQR)
((df2 < (Q1 - 2 * IQR)) | (df2 > (Q3 + 2 * IQR))).any()
# Out:
# tmpf    False
# dwpf    False
# relh    False
# drct    False
# sknt     True
# HE      False
# MWh      True
# dtype: bool

# %%
#Upper and Lower limits using standard definition. This will be used to replace the outlier values if necessary (Based on team's discussion)
dict={}
for col in df2.columns:
  percentile75=df2[col].quantile(0.75)
  percentile25=df2[col].quantile(0.25)
  IQR=percentile75-percentile25
  upper_limit=percentile75+2*IQR
  lower_limit=percentile25-2*IQR
  dict['upper_limit'+'_'+col]=upper_limit
  dict['lower_limit'+'_'+col]=lower_limit

dict
# Out:
# {'upper_limit_tmpf': 100.8,
#  'lower_limit_tmpf': 36.300000000000004,
#  'upper_limit_dwpf': 90.75000000000001,
#  'lower_limit_dwpf': 20.624999999999986,
#  'upper_limit_relh': 171.73499999999996,
#  'lower_limit_relh': -31.602499999999978,
#  'upper_limit_drct': 545.0,
#  'lower_limit_drct': 32.5,
#  'upper_limit_sknt': 23.75,
#  'lower_limit_sknt': -7.5,
#  'upper_limit_HE': 40.25,
#  'lower_limit_HE': -17.25,
#  'upper_limit_MWh': 20258.995000000003,
#  'lower_limit_MWh': 7910.782500000001}

# %% [markdown]
# Column: sknt

# %%
cond = df2.sknt>dict.get('upper_limit_sknt')
df2.loc[cond,'sknt']=dict.get('upper_limit_sknt')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %% [markdown]
# Column: drct

# %%
cond = df2.drct<dict.get('lower_limit_drct')
df2.loc[cond,'drct']=dict.get('lower_limit_drct')

# %% [markdown]
# Column: MWh

# %%
cond = df2.MWh>dict.get('upper_limit_MWh')
#df2[cond]
df2.loc[cond,'MWh']=dict.get('upper_limit_MWh')

# %%
sns.pairplot(
    data=df2, 
    aspect=.85);

# %%
#Check for count of outliers based on standard definition of lower quartile and upper quartile
#Insur_data_cont
df2.describe()
Q1 = df2.quantile(0.25)
Q3 = df2.quantile(0.75)
IQR = Q3 - Q1
#print(IQR)
((df2 < (Q1 - 2* IQR)) | (df2 > (Q3 + 2 * IQR))).any()
# Out:
# tmpf    False
# dwpf    False
# relh    False
# drct    False
# sknt    False
# HE      False
# MWh     False
# dtype: bool

# %% [markdown]
# ## Data Preparation for Modeling

# %%
# we know our target variable is 'median_house_value'
y = df2['MWh']
X = df2.drop('MWh', axis=1)
print(X.shape, y.shape)
# Out:
# (96, 6) (96,)

# %%
# convert to numpy array
X = np.array(X)
y = np.array(y)

# %%
# split into X_train and X_test
# always split into X_train, X_test first THEN apply minmax scaler
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    random_state=12)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (76, 6) (20, 6) (76,) (20,)

# %%
# use minMax scaler
min_max_scaler = MinMaxScaler()
X_train = min_max_scaler.fit_transform(X_train)
X_test = min_max_scaler.transform(X_test)

# %% [markdown]
# ## Data Modeling (4 Hidden layers, RELU and RMSPROP optimizer)

# %%
X_train.shape[1]
# Out:
# 6

# %%
# build the model!
model = Sequential()
model.add(Dense(5, input_shape=(X_train.shape[1],), activation='relu')) # (features,)
model.add(Dense(3, activation='relu'))
model.add(Dense(9, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(1, activation='linear')) # output node
model.summary() # see what your model looks like
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_27 (Dense)            (None, 5)                 35
#
#  dense_28 (Dense)            (None, 3)                 18
#
#  dense_29 (Dense)            (None, 9)                 36
#
#  dense_30 (Dense)            (None, 12)                120
#
#  dense_31 (Dense)            (None, 1)                 13
#
# ...
# Total params: 222
# Trainable params: 222
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
# !pip install keras-visualizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from keras_visualizer import visualizer 
visualizer(model, format='png', view=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Compiling the Model

# %%
# compile the model
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %% [markdown]
# ### Fit the Model

# %%
# early stopping callback
es = EarlyStopping(monitor='val_loss',
                   mode='min',
                   patience=10, # you can choose a big value!
                   restore_best_weights = True) # don't forget this! otherwise it's potentially suboptimal weights

# %%
# fit the model!
# remember, assign it to a new variable called 'history' in case
# we want to look at the learning curves

history = model.fit(X_train, y_train,
                    validation_data = (X_test, y_test),
                    callbacks=[es], # early stopping callbacks
                    epochs=5000, # set this to a big number
                    batch_size=10, # this is a hyperparameter
                    shuffle=True, # it's a best practice to shuffle your data
                    verbose=1) # this prints the output as the model trains
# Out:
# Epoch 1/5000
# 8/8 [==============================] - 2s 57ms/step - loss: 204360256.0000 - mae: 14107.8867 - val_loss: 248099840.0000 - val_mae: 15561.0215
# Epoch 2/5000
# 8/8 [==============================] - 0s 15ms/step - loss: 204358384.0000 - mae: 14107.8193 - val_loss: 248098512.0000 - val_mae: 15560.9814
# Epoch 3/5000
# 8/8 [==============================] - 0s 16ms/step - loss: 204357360.0000 - mae: 14107.7812 - val_loss: 248097440.0000 - val_mae: 15560.9473
# Epoch 4/5000
# 8/8 [==============================] - 0s 17ms/step - loss: 204356480.0000 - mae: 14107.7529 - val_loss: 248096464.0000 - val_mae: 15560.9160
# Epoch 5/5000
# 8/8 [==============================] - 0s 16ms/step - loss: 204355712.0000 - mae: 14107.7256 - val_loss: 248095648.0000 - val_mae: 15560.8906
# Epoch 6/5000
# 8/8 [==============================] - 0s 17ms/step - loss: 204354960.0000 - mae: 14107.7002 - val_loss: 248094816.0000 - val_mae: 15560.8623
# Epoch 7/5000
# ...

# %% [markdown]
# ## Evaluate the Model

# %%
# let's see the training and validation accuracy by epoch
history_dict = history.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# let's see the training and validation accuracy by epoch
history_dict = history.history
loss_values = history_dict['mae'] # you can change this
val_loss_values = history_dict['val_mae'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training mae')
plt.plot(epochs, val_loss_values, 'orange', label='Validation mae')
plt.title('Training and validation mae')
plt.xlabel('Epochs')
plt.ylabel('mae')
plt.legend()
plt.show()

# %% [markdown]
# ### Scatterplots of Actual vs Predicted

# %%
# scatterplot of actual vs. pred
# specify the dimensions 
fig, axes = plt.subplots(1,2) # 1 row, 2 columns

# this makes the individual subplots
# Training Results
axes[0].scatter(x=y_train, y=model.predict(X_train)) #first row, first entry (left top)
axes[0].set_xlabel("Actual", fontsize=10)
axes[0].set_ylabel("Predicted",  fontsize=10)
axes[0].set_title("Training")
# add 45 deg line
x = np.linspace(*axes[0].get_xlim())
axes[0].plot(x, x, color='red')
# Validation Results
axes[1].scatter(x=y_test, y=model.predict(X_test)) # first row, second entry (right top)
axes[1].set_xlabel("Actual", fontsize=10)
axes[1].set_ylabel("Predicted",  fontsize=10)
axes[1].set_title("Validation")
# add 45 deg line
x = np.linspace(*axes[1].get_xlim())
axes[1].plot(x, x, color='red')

# tight layout
fig.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ### Evaluation Metrics

# %%
# metrics

pred = model.predict(X_test)
pred

trainpreds = model.predict(X_train)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

print("MAE value for training data is",mean_absolute_error(y_train, trainpreds)) # train
print("MAE value for test data is",mean_absolute_error(y_test, pred)) # test

print("R-squared value for training data is",r2_score(y_train, trainpreds)) # train
print("R-squared value for test data is",r2_score(y_test, pred)) # test

print("Mean sqaured value for training data is",mean_squared_error(y_train, trainpreds)) # train
print("Mean sqaured value for training data is",mean_squared_error(y_test, pred)) # test
# Out:
# MAE value for training data is 1445.8478340871711
# MAE value for test data is 1712.5786601562504
# R-squared value for training data is 0.3686841094710023
# R-squared value for test data is 0.25986290688153246
# Mean sqaured value for training data is 3363500.95878412
# Mean sqaured value for training data is 4407025.8659643475

# %% [markdown]
# ## Dropout

# %%
# resets names in the model summary
from keras import backend as K
K.clear_session()

# %%
# build the model!
model = Sequential()
model.add(Dense(5, input_shape=(X_train.shape[1],), activation='relu')) # (features,)
model.add(Dropout(0.2)) # specify a percentage between 0 and 0.5
model.add(Dense(3, activation='relu'))
model.add(Dropout(0.2)) # specify a percentage between 0 and 0.5
model.add(Dense(9, activation='relu'))
model.add(Dropout(0.2)) # specify a percentage between 0 and 0.5
model.add(Dense(12, activation='relu'))
model.add(Dropout(0.2)) # specify a percentage between 0 and 0.5
model.add(Dense(1, activation='linear')) # output node
model.summary() # see what your model looks like
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 5)                 35
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 3)                 18
#
#  dropout_1 (Dropout)         (None, 3)                 0
#
#  dense_2 (Dense)             (None, 9)                 36
#
#  dropout_2 (Dropout)         (None, 9)                 0
#
#  dense_3 (Dense)             (None, 12)                120
#
#  dropout_3 (Dropout)         (None, 12)                0
#
#  dense_4 (Dense)             (None, 1)                 13
#
# ...
# Total params: 222
# Trainable params: 222
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
# !pip install keras-visualizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from keras_visualizer import visualizer 
visualizer(model, format='png', view=True)

# %% [markdown]
# ### Compiling the Model

# %%
# compile the model
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %% [markdown]
# ### Fit the Model

# %%
# early stopping callback
es = EarlyStopping(monitor='val_loss',
                   mode='min',
                   patience=10, # you can choose a big value!
                   restore_best_weights = True) # don't forget this! otherwise it's potentially suboptimal weights

# %%
# fit the model!
# remember, assign it to a new variable called 'history' in case
# we want to look at the learning curves

history = model.fit(X_train, y_train,
                    validation_data = (X_test, y_test),
                    callbacks=[es], # early stopping callbacks
                    epochs=5000, # set this to a big number
                    batch_size=10, # this is a hyperparameter
                    shuffle=True, # it's a best practice to shuffle your data
                    verbose=1) # this prints the output as the model trains
# Out:
# Epoch 1/5000
# 8/8 [==============================] - 2s 126ms/step - loss: 204345984.0000 - mae: 14107.3828 - val_loss: 248084432.0000 - val_mae: 15560.5342
# Epoch 2/5000
# 8/8 [==============================] - 0s 11ms/step - loss: 204344832.0000 - mae: 14107.3311 - val_loss: 248078720.0000 - val_mae: 15560.3486
# Epoch 3/5000
# 8/8 [==============================] - 0s 10ms/step - loss: 204338544.0000 - mae: 14107.1016 - val_loss: 248072832.0000 - val_mae: 15560.1582
# Epoch 4/5000
# 8/8 [==============================] - 0s 9ms/step - loss: 204334096.0000 - mae: 14106.9688 - val_loss: 248066256.0000 - val_mae: 15559.9453
# Epoch 5/5000
# 8/8 [==============================] - 0s 9ms/step - loss: 204325936.0000 - mae: 14106.6631 - val_loss: 248058976.0000 - val_mae: 15559.7090
# Epoch 6/5000
# 8/8 [==============================] - 0s 10ms/step - loss: 204316800.0000 - mae: 14106.3516 - val_loss: 248051504.0000 - val_mae: 15559.4707
# Epoch 7/5000
# ...

# %% [markdown]
# ### Evaluate the Model

# %%
# let's see the training and validation accuracy by epoch
history_dict = history.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# let's see the training and validation accuracy by epoch
history_dict = history.history
loss_values = history_dict['mae'] # you can change this
val_loss_values = history_dict['val_mae'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training mae')
plt.plot(epochs, val_loss_values, 'orange', label='Validation mae')
plt.title('Training and validation mae')
plt.xlabel('Epochs')
plt.ylabel('mae')
plt.legend()
plt.show()

# %% [markdown]
# ### Scatterplots of Actual vs Predicted

# %%
# scatterplot of actual vs. pred
# specify the dimensions 
fig, axes = plt.subplots(1,2) # 1 row, 2 columns

# this makes the individual subplots
# Training Results
axes[0].scatter(x=y_train, y=model.predict(X_train)) #first row, first entry (left top)
axes[0].set_xlabel("Actual", fontsize=10)
axes[0].set_ylabel("Predicted",  fontsize=10)
axes[0].set_title("Training")
# add 45 deg line
x = np.linspace(*axes[0].get_xlim())
axes[0].plot(x, x, color='red')
# Validation Results
axes[1].scatter(x=y_test, y=model.predict(X_test)) # first row, second entry (right top)
axes[1].set_xlabel("Actual", fontsize=10)
axes[1].set_ylabel("Predicted",  fontsize=10)
axes[1].set_title("Validation")
# add 45 deg line
x = np.linspace(*axes[1].get_xlim())
axes[1].plot(x, x, color='red')

# tight layout
fig.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ### Evaluation Metrics

# %%
# metrics

pred = model.predict(X_test)
pred

trainpreds = model.predict(X_train)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

print("MAE value for training data is",mean_absolute_error(y_train, trainpreds)) # train
print("MAE value for test data is",mean_absolute_error(y_test, pred)) # test

print("R-squared value for training data is",r2_score(y_train, trainpreds)) # train
print("R-squared value for test data is",r2_score(y_test, pred)) # test

print("Mean sqaured value for training data is",mean_squared_error(y_train, trainpreds)) # train
print("Mean sqaured value for training data is",mean_squared_error(y_test, pred)) # test
# Out:
# MAE value for training data is 2869.003748715049
# MAE value for test data is 3609.8186484375
# R-squared value for training data is -1.0624861941104036
# R-squared value for test data is -1.9718775073998644
# Mean sqaured value for training data is 10988436.05149317
# Mean sqaured value for training data is 17695560.953992754

# %% [markdown]
# ## Data Model - Trail 2 (Two layers with 8 units, RELU and RGSPROP)

# %%
# build the model!
model = Sequential()
model.add(Dense(5, input_shape=(X_train.shape[1],), activation='relu')) # (features,)
model.add(Dense(3, activation='relu'))
# model.add(Dense(9, activation='relu'))
# model.add(Dense(12, activation='relu'))
model.add(Dense(1, activation='linear')) # output node
model.summary() # see what your model looks like
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_5 (Dense)             (None, 5)                 35
#
#  dense_6 (Dense)             (None, 3)                 18
#
#  dense_7 (Dense)             (None, 1)                 4
#
# ...
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
# !pip install keras-visualizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from keras_visualizer import visualizer 
visualizer(model, format='png', view=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Compiling the Model

# %%
# compile the model
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %% [markdown]
# ### Fit the Model

# %%
# early stopping callback
es = EarlyStopping(monitor='val_loss',
                   mode='min',
                   patience=10, # you can choose a big value!
                   restore_best_weights = True) # don't forget this! otherwise it's potentially suboptimal weights

# %%
# fit the model!
# remember, assign it to a new variable called 'history' in case
# we want to look at the learning curves

history = model.fit(X_train, y_train,
                    validation_data = (X_test, y_test),
                    callbacks=[es], # early stopping callbacks
                    epochs=5000, # set this to a big number
                    batch_size=10, # this is a hyperparameter
                    shuffle=True, # it's a best practice to shuffle your data
                    verbose=1) # this prints the output as the model trains
# Out:
# Epoch 1/5000
# 8/8 [==============================] - 1s 44ms/step - loss: 204351760.0000 - mae: 14107.5869 - val_loss: 248091136.0000 - val_mae: 15560.7529
# Epoch 2/5000
# 8/8 [==============================] - 0s 9ms/step - loss: 204350160.0000 - mae: 14107.5293 - val_loss: 248089632.0000 - val_mae: 15560.7061
# Epoch 3/5000
# 8/8 [==============================] - 0s 12ms/step - loss: 204348848.0000 - mae: 14107.4834 - val_loss: 248088160.0000 - val_mae: 15560.6592
# Epoch 4/5000
# 8/8 [==============================] - 0s 11ms/step - loss: 204347584.0000 - mae: 14107.4395 - val_loss: 248086752.0000 - val_mae: 15560.6152
# Epoch 5/5000
# 8/8 [==============================] - 0s 10ms/step - loss: 204346304.0000 - mae: 14107.3936 - val_loss: 248085280.0000 - val_mae: 15560.5674
# Epoch 6/5000
# 8/8 [==============================] - 0s 8ms/step - loss: 204344976.0000 - mae: 14107.3467 - val_loss: 248083760.0000 - val_mae: 15560.5205
# Epoch 7/5000
# ...

# %% [markdown]
# ### Evaluate the Model

# %%
# let's see the training and validation accuracy by epoch
history_dict = history.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# let's see the training and validation accuracy by epoch
history_dict = history.history
loss_values = history_dict['mae'] # you can change this
val_loss_values = history_dict['val_mae'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training mae')
plt.plot(epochs, val_loss_values, 'orange', label='Validation mae')
plt.title('Training and validation mae')
plt.xlabel('Epochs')
plt.ylabel('mae')
plt.legend()
plt.show()

# %% [markdown]
# ### Scatterplots of Actual vs Predicted

# %%
# scatterplot of actual vs. pred
# specify the dimensions 
fig, axes = plt.subplots(1,2) # 1 row, 2 columns

# this makes the individual subplots
# Training Results
axes[0].scatter(x=y_train, y=model.predict(X_train)) #first row, first entry (left top)
axes[0].set_xlabel("Actual", fontsize=10)
axes[0].set_ylabel("Predicted",  fontsize=10)
axes[0].set_title("Training")
# add 45 deg line
x = np.linspace(*axes[0].get_xlim())
axes[0].plot(x, x, color='red')
# Validation Results
axes[1].scatter(x=y_test, y=model.predict(X_test)) # first row, second entry (right top)
axes[1].set_xlabel("Actual", fontsize=10)
axes[1].set_ylabel("Predicted",  fontsize=10)
axes[1].set_title("Validation")
# add 45 deg line
x = np.linspace(*axes[1].get_xlim())
axes[1].plot(x, x, color='red')

# tight layout
fig.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ### Evaluation Metrics

# %%
# metrics

pred = model.predict(X_test)
pred

trainpreds = model.predict(X_train)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

print("MAE value for training data is",mean_absolute_error(y_train, trainpreds)) # train
print("MAE value for test data is",mean_absolute_error(y_test, pred)) # test

print("R-squared value for training data is",r2_score(y_train, trainpreds)) # train
print("R-squared value for test data is",r2_score(y_test, pred)) # test

print("Mean sqaured value for training data is",mean_squared_error(y_train, trainpreds)) # train
print("Mean sqaured value for training data is",mean_squared_error(y_test, pred)) # test
# Out:
# MAE value for training data is 1456.2207000411188
# MAE value for test data is 1792.7316386718753
# R-squared value for training data is 0.3254758425561515
# R-squared value for test data is 0.18701286645453719
# Mean sqaured value for training data is 3593704.331415409
# Mean sqaured value for training data is 4840799.575569425

# %%
# metrics

pred = model.predict(X_test)
pred

trainpreds = model.predict(X_train)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

print(mean_absolute_error(y_train, trainpreds)) # train
print(mean_absolute_error(y_test, pred)) # test

print(r2_score(y_train, trainpreds)) # train
print(r2_score(y_test, pred)) # test

print(mean_squared_error(y_train, trainpreds)) # train
print(mean_squared_error(y_test, pred)) # test
# Out:
# 1456.2207000411188
# 1792.7316386718753
# 0.3254758425561515
# 0.18701286645453719
# 3593704.331415409
# 4840799.575569425

# %% [markdown]
# ## Data Model - Trail 3 (Only one layer and 3 units with RELU and RGSPROP optimizer)

# %%
# build the model!
model = Sequential()
model.add(Dense(3, input_shape=(X_train.shape[1],), activation='relu')) # (features,)
# model.add(Dense(9, activation='relu'))
# model.add(Dense(12, activation='relu'))
model.add(Dense(1, activation='linear')) # output node
model.summary() # see what your model looks like
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 3)                 21
#
#  dense_9 (Dense)             (None, 1)                 4
#
# ...
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
# !pip install keras-visualizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from keras_visualizer import visualizer 
visualizer(model, format='png', view=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Compiling the Model

# %%
# compile the model
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %% [markdown]
# ### Fit the Model

# %%
# early stopping callback
es = EarlyStopping(monitor='val_loss',
                   mode='min',
                   patience=5, # you can choose a big value!
                   restore_best_weights = True) # don't forget this! otherwise it's potentially suboptimal weights

# %%
# fit the model!
# remember, assign it to a new variable called 'history' in case
# we want to look at the learning curves

history = model.fit(X_train, y_train,
                    validation_data = (X_test, y_test),
                    callbacks=[es], # early stopping callbacks
                    epochs=5000, # set this to a big number
                    batch_size=10, # this is a hyperparameter
                    shuffle=True, # it's a best practice to shuffle your data
                    verbose=1) # this prints the output as the model trains
# Out:
# Streaming output truncated to the last 5000 lines.
# 8/8 [==============================] - 0s 9ms/step - loss: 203794752.0000 - mae: 14087.8320 - val_loss: 247477088.0000 - val_mae: 15541.0029
# Epoch 2502/5000
# 8/8 [==============================] - 0s 10ms/step - loss: 203794528.0000 - mae: 14087.8242 - val_loss: 247476832.0000 - val_mae: 15540.9941
# Epoch 2503/5000
# 8/8 [==============================] - 0s 10ms/step - loss: 203794288.0000 - mae: 14087.8154 - val_loss: 247476576.0000 - val_mae: 15540.9863
# Epoch 2504/5000
# 8/8 [==============================] - 0s 9ms/step - loss: 203794064.0000 - mae: 14087.8057 - val_loss: 247476320.0000 - val_mae: 15540.9785
# Epoch 2505/5000
# 8/8 [==============================] - 0s 8ms/step - loss: 203793824.0000 - mae: 14087.7998 - val_loss: 247476096.0000 - val_mae: 15540.9707
# Epoch 2506/5000
# ...

# %% [markdown]
# ### Evaluate the Model

# %%
# let's see the training and validation accuracy by epoch
history_dict = history.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# let's see the training and validation accuracy by epoch
history_dict = history.history
loss_values = history_dict['mae'] # you can change this
val_loss_values = history_dict['val_mae'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training mae')
plt.plot(epochs, val_loss_values, 'orange', label='Validation mae')
plt.title('Training and validation mae')
plt.xlabel('Epochs')
plt.ylabel('mae')
plt.legend()
plt.show()

# %% [markdown]
# ### Scatterplots of Actual vs Predicted

# %%
# scatterplot of actual vs. pred
# specify the dimensions 
fig, axes = plt.subplots(1,2) # 1 row, 2 columns

# this makes the individual subplots
# Training Results
axes[0].scatter(x=y_train, y=model.predict(X_train)) #first row, first entry (left top)
axes[0].set_xlabel("Actual", fontsize=10)
axes[0].set_ylabel("Predicted",  fontsize=10)
axes[0].set_title("Training")
# add 45 deg line
x = np.linspace(*axes[0].get_xlim())
axes[0].plot(x, x, color='red')
# Validation Results
axes[1].scatter(x=y_test, y=model.predict(X_test)) # first row, second entry (right top)
axes[1].set_xlabel("Actual", fontsize=10)
axes[1].set_ylabel("Predicted",  fontsize=10)
axes[1].set_title("Validation")
# add 45 deg line
x = np.linspace(*axes[1].get_xlim())
axes[1].plot(x, x, color='red')

# tight layout
fig.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ### Evaluation Metrics

# %%
# metrics

pred = model.predict(X_test)
pred

trainpreds = model.predict(X_train)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

print("MAE value for training data is",mean_absolute_error(y_train, trainpreds)) # train
print("MAE value for test data is",mean_absolute_error(y_test, pred)) # test

print("R-squared value for training data is",r2_score(y_train, trainpreds)) # train
print("R-squared value for test data is",r2_score(y_test, pred)) # test

print("Mean sqaured value for training data is",mean_squared_error(y_train, trainpreds)) # train
print("Mean sqaured value for training data is",mean_squared_error(y_test, pred)) # test
# Out:
# MAE value for training data is 14067.862759784899
# MAE value for test data is 15521.038457153321
# R-squared value for training data is -37.14594495126318
# R-squared value for test data is -40.458345664343916
# Mean sqaured value for training data is 203232524.86135024
# Mean sqaured value for training data is 246856972.04154307

# %% [markdown]
# ## Data Model - Trail 4 (Same as Trail 2 but with high patience and lower batchsize)

# %%
# build the model!
model = Sequential()
model.add(Dense(5, input_shape=(X_train.shape[1],), activation='relu')) # (features,)
model.add(Dense(3, activation='relu'))
# model.add(Dense(9, activation='relu'))
# model.add(Dense(12, activation='relu'))
model.add(Dense(1, activation='linear')) # output node
model.summary() # see what your model looks like
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 5)                 35
#
#  dense_11 (Dense)            (None, 3)                 18
#
#  dense_12 (Dense)            (None, 1)                 4
#
# ...
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
# !pip install keras-visualizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from keras_visualizer import visualizer 
visualizer(model, format='png', view=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Compiling the Model

# %%
# compile the model
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %% [markdown]
# ### Fit the Model

# %%
# early stopping callback
es = EarlyStopping(monitor='val_loss',
                   mode='min',
                   patience=10, # you can choose a big value!
                   restore_best_weights = True) # don't forget this! otherwise it's potentially suboptimal weights

# %%
# fit the model!
# remember, assign it to a new variable called 'history' in case
# we want to look at the learning curves

history = model.fit(X_train, y_train,
                    validation_data = (X_test, y_test),
                    callbacks=[es], # early stopping callbacks
                    epochs=5000, # set this to a big number
                    batch_size=1, # this is a hyperparameter
                    shuffle=True, # it's a best practice to shuffle your data
                    verbose=1) # this prints the output as the model trains
# Out:
# Epoch 1/5000
# 76/76 [==============================] - 2s 13ms/step - loss: 204325376.0000 - mae: 14106.6807 - val_loss: 248049104.0000 - val_mae: 15559.4141
# Epoch 2/5000
# 76/76 [==============================] - 1s 7ms/step - loss: 204304704.0000 - mae: 14105.9453 - val_loss: 248023296.0000 - val_mae: 15558.5908
# Epoch 3/5000
# 76/76 [==============================] - 0s 6ms/step - loss: 204278288.0000 - mae: 14105.0264 - val_loss: 247988896.0000 - val_mae: 15557.4893
# Epoch 4/5000
# 76/76 [==============================] - 1s 7ms/step - loss: 204244176.0000 - mae: 14103.8389 - val_loss: 247944352.0000 - val_mae: 15556.0684
# Epoch 5/5000
# 76/76 [==============================] - 1s 7ms/step - loss: 204199584.0000 - mae: 14102.2939 - val_loss: 247885536.0000 - val_mae: 15554.1924
# Epoch 6/5000
# 76/76 [==============================] - 0s 7ms/step - loss: 204144448.0000 - mae: 14100.3457 - val_loss: 247813712.0000 - val_mae: 15551.9014
# Epoch 7/5000
# ...

# %% [markdown]
# ### Evaluate the Model

# %%
# let's see the training and validation accuracy by epoch
history_dict = history.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# let's see the training and validation accuracy by epoch
history_dict = history.history
loss_values = history_dict['mae'] # you can change this
val_loss_values = history_dict['val_mae'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training mae')
plt.plot(epochs, val_loss_values, 'orange', label='Validation mae')
plt.title('Training and validation mae')
plt.xlabel('Epochs')
plt.ylabel('mae')
plt.legend()
plt.show()

# %% [markdown]
# ### Scatterplots of Actual vs Predicted

# %%
# scatterplot of actual vs. pred
# specify the dimensions 
fig, axes = plt.subplots(1,2) # 1 row, 2 columns

# this makes the individual subplots
# Training Results
axes[0].scatter(x=y_train, y=model.predict(X_train)) #first row, first entry (left top)
axes[0].set_xlabel("Actual", fontsize=10)
axes[0].set_ylabel("Predicted",  fontsize=10)
axes[0].set_title("Training")
# add 45 deg line
x = np.linspace(*axes[0].get_xlim())
axes[0].plot(x, x, color='red')
# Validation Results
axes[1].scatter(x=y_test, y=model.predict(X_test)) # first row, second entry (right top)
axes[1].set_xlabel("Actual", fontsize=10)
axes[1].set_ylabel("Predicted",  fontsize=10)
axes[1].set_title("Validation")
# add 45 deg line
x = np.linspace(*axes[1].get_xlim())
axes[1].plot(x, x, color='red')

# tight layout
fig.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ### Evaluation Metrics

# %%
# metrics

pred = model.predict(X_test)
pred

trainpreds = model.predict(X_train)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

print("MAE value for training data is",mean_absolute_error(y_train, trainpreds)) # train
print("MAE value for test data is",mean_absolute_error(y_test, pred)) # test

print("R-squared value for training data is",r2_score(y_train, trainpreds)) # train
print("R-squared value for test data is",r2_score(y_test, pred)) # test

print("Mean sqaured value for training data is",mean_squared_error(y_train, trainpreds)) # train
print("Mean sqaured value for training data is",mean_squared_error(y_test, pred)) # test
# Out:
# MAE value for training data is 1457.4579872532895
# MAE value for test data is 1852.1208476562504
# R-squared value for training data is 0.3032495529761101
# R-squared value for test data is 0.14675890011558457
# Mean sqaured value for training data is 3712120.717624286
# Mean sqaured value for training data is 5080485.266926914

# %% [markdown]
# ## Data Model - Trail 5 (SGD with two hidden layers)

# %%
# build the model!
model = Sequential()
model.add(Dense(5, input_shape=(X_train.shape[1],), activation='relu')) # (features,)
model.add(Dense(3, activation='relu'))
# model.add(Dense(9, activation='relu'))
# model.add(Dense(12, activation='relu'))
model.add(Dense(1, activation='linear')) # output node
model.summary() # see what your model looks like
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_13 (Dense)            (None, 5)                 35
#
#  dense_14 (Dense)            (None, 3)                 18
#
#  dense_15 (Dense)            (None, 1)                 4
#
# ...
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
# !pip install keras-visualizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from keras_visualizer import visualizer 
visualizer(model, format='png', view=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Compiling the Model

# %%
# compile the model
model.compile(optimizer='SGD', loss='mse', metrics=['mae'])

# %% [markdown]
# ### Fit the Model

# %%
# early stopping callback
es = EarlyStopping(monitor='val_loss',
                   mode='min',
                   patience=10, # you can choose a big value!
                   restore_best_weights = True) # don't forget this! otherwise it's potentially suboptimal weights

# %%
# fit the model!
# remember, assign it to a new variable called 'history' in case
# we want to look at the learning curves

history = model.fit(X_train, y_train,
                    validation_data = (X_test, y_test),
                    callbacks=[es], # early stopping callbacks
                    epochs=5000, # set this to a big number
                    batch_size=10, # this is a hyperparameter
                    shuffle=True, # it's a best practice to shuffle your data
                    verbose=1) # this prints the output as the model trains
# Out:
# Epoch 1/5000
# 8/8 [==============================] - 2s 76ms/step - loss: 180115200.0000 - mae: 13199.6738 - val_loss: 187032112.0000 - val_mae: 13456.5127
# Epoch 2/5000
# 8/8 [==============================] - 0s 23ms/step - loss: 131860560.0000 - mae: 11237.2520 - val_loss: 141996448.0000 - val_mae: 11663.7090
# Epoch 3/5000
# 8/8 [==============================] - 0s 18ms/step - loss: 96857712.0000 - mae: 9561.4434 - val_loss: 108560656.0000 - val_mae: 10129.4785
# Epoch 4/5000
# 8/8 [==============================] - 0s 27ms/step - loss: 71407936.0000 - mae: 8137.9004 - val_loss: 83913664.0000 - val_mae: 8829.4580
# Epoch 5/5000
# 8/8 [==============================] - 0s 18ms/step - loss: 53122708.0000 - mae: 6894.3477 - val_loss: 65824128.0000 - val_mae: 7737.5571
# Epoch 6/5000
# 8/8 [==============================] - 0s 16ms/step - loss: 40017484.0000 - mae: 5885.5244 - val_loss: 52167944.0000 - val_mae: 6798.0586
# Epoch 7/5000
# ...

# %% [markdown]
# ### Evaluate the Model

# %%
# let's see the training and validation accuracy by epoch
history_dict = history.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# let's see the training and validation accuracy by epoch
history_dict = history.history
loss_values = history_dict['mae'] # you can change this
val_loss_values = history_dict['val_mae'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training mae')
plt.plot(epochs, val_loss_values, 'orange', label='Validation mae')
plt.title('Training and validation mae')
plt.xlabel('Epochs')
plt.ylabel('mae')
plt.legend()
plt.show()

# %% [markdown]
# ### Scatterplots of Actual vs Predicted

# %%
# scatterplot of actual vs. pred
# specify the dimensions 
fig, axes = plt.subplots(1,2) # 1 row, 2 columns

# this makes the individual subplots
# Training Results
axes[0].scatter(x=y_train, y=model.predict(X_train)) #first row, first entry (left top)
axes[0].set_xlabel("Actual", fontsize=10)
axes[0].set_ylabel("Predicted",  fontsize=10)
axes[0].set_title("Training")
# add 45 deg line
x = np.linspace(*axes[0].get_xlim())
axes[0].plot(x, x, color='red')
# Validation Results
axes[1].scatter(x=y_test, y=model.predict(X_test)) # first row, second entry (right top)
axes[1].set_xlabel("Actual", fontsize=10)
axes[1].set_ylabel("Predicted",  fontsize=10)
axes[1].set_title("Validation")
# add 45 deg line
x = np.linspace(*axes[1].get_xlim())
axes[1].plot(x, x, color='red')

# tight layout
fig.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ### Evaluation Metrics

# %%
# metrics

pred = model.predict(X_test)
pred

trainpreds = model.predict(X_train)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

print("MAE value for training data is",mean_absolute_error(y_train, trainpreds)) # train
print("MAE value for test data is",mean_absolute_error(y_test, pred)) # test

print("R-squared value for training data is",r2_score(y_train, trainpreds)) # train
print("R-squared value for test data is",r2_score(y_test, pred)) # test

print("Mean sqaured value for training data is",mean_squared_error(y_train, trainpreds)) # train
print("Mean sqaured value for training data is",mean_squared_error(y_test, pred)) # test
# Out:
# MAE value for training data is 1815.6593811677633
# MAE value for test data is 1961.2379843750005
# R-squared value for training data is -2.1910548182457745e-06
# R-squared value for test data is -0.3563219789076373
# Mean sqaured value for training data is 5327773.906626558
# Mean sqaured value for training data is 8075998.486222556

# %% [markdown]
# ## Findings/Learnings

# %% [markdown]
# Out of 5 different models, model(Data model 1) with two hidden layers and RMSPROP optimizer gave better results
#
# 1.   Model data performs differently for different optimizer functions. For this particular data, RMSPROP is performing better than SGD
# 2.   Model with more hidden layers(Non-funnel type) is performing worse comapred to models with fewer hidden layers and funnel type. Model learns better in converging layers compared to diverging layers
# 3. Lower batch size model took more time to learn and does not give the best result as it could not learn completely in 5000 epochs
# 4. SGD model was trying to predict every value as mean. So even though, MAE is less, R-squared value is negative
# 5. More number of hidden layers does not give the best result always, it depends on the data where the model may learn based on other parameters such as patience, batch size and number of units in the hidden layers
